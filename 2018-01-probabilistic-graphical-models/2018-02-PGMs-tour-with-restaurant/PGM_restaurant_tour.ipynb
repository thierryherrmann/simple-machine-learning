# %% [markdown]
# # This is a Small Tour about Probabilistic Graphical Models using pgmpy
#
# Ensure these versions are installed:
# - conda install pandas=0.18.1 numpy=1.11.1 networkx=1.11 scipy=0.18.0  jupyter
# - conda install -c ankurankan pgmpy
# - conda install jupyter
#
# Verify occasionally on https://github.com/pgmpy/pgmpy

# %% [markdown]
# ## Restaurant CPDs
# #### Borrowed from the excellent book *Mastering Probabilistic Graphical Models Using Python* from Abinash Panda, Ankur Ankan
#
# #### Verifications and tests made with Samiam: http://reasoning.cs.ucla.edu/samiam/
# ![restaurant_CPDs](restaurant_CPDs.png)

# %%
import numpy as np
import pandas as pd
import datetime
from pgmpy.models import BayesianModel
from pgmpy.inference import VariableElimination
from pgmpy.factors.discrete import TabularCPD
# Now first create the model.
restaurant = BayesianModel([('location', 'cost'),
                            ('quality', 'cost'),
                            ('cost', 'no_of_people'),
                            ('location', 'no_of_people')])
cpd_location = TabularCPD('location', 2, [[0.6, 0.4]])
cpd_quality = TabularCPD('quality', 3, [[0.3, 0.5, 0.2]])
cpd_cost = TabularCPD('cost', 2,
                      [[0.8, 0.6, 0.1, 0.6, 0.6, 0.05],
                       [0.2, 0.4, 0.9, 0.4, 0.4, 0.95]],
                      ['location', 'quality'], [2, 3])
cpd_no_of_people = TabularCPD('no_of_people', 2,
                              [[0.6, 0.8, 0.1, 0.6],
                               [0.4, 0.2, 0.9, 0.4]],
                              ['location', 'cost'], [2, 2])
restaurant.add_cpds(cpd_location, cpd_quality,
                    cpd_cost, cpd_no_of_people)

# %%
print(cpd_location)
print(cpd_quality)
print(cpd_cost)
print(cpd_no_of_people)
# Out:
# ╒════════════╤═════╕
# │ location_0 │ 0.6 │
# ├────────────┼─────┤
# │ location_1 │ 0.4 │
# ╘════════════╧═════╛
# ╒═══════════╤═════╕
# │ quality_0 │ 0.3 │
# ├───────────┼─────┤
# │ quality_1 │ 0.5 │
# ├───────────┼─────┤
# │ quality_2 │ 0.2 │
# ╘═══════════╧═════╛
# ╒══════════╤════════════╤════════════╤════════════╤════════════╤════════════╤════════════╕
# │ location │ location_0 │ location_0 │ location_0 │ location_1 │ location_1 │ location_1 │
# ├──────────┼────────────┼────────────┼────────────┼────────────┼────────────┼────────────┤
# │ quality  │ quality_0  │ quality_1  │ quality_2  │ quality_0  │ quality_1  │ quality_2  │
# ├──────────┼────────────┼────────────┼────────────┼────────────┼────────────┼────────────┤
# │ cost_0   │ 0.8        │ 0.6        │ 0.1        │ 0.6        │ 0.6        │ 0.05       │
# ├──────────┼────────────┼────────────┼────────────┼────────────┼────────────┼────────────┤
# │ cost_1   │ 0.2        │ 0.4        │ 0.9        │ 0.4        │ 0.4        │ 0.95       │
# ╘══════════╧════════════╧════════════╧════════════╧════════════╧════════════╧════════════╛
# ╒════════════════╤════════════╤════════════╤════════════╤════════════╕
# │ location       │ location_0 │ location_0 │ location_1 │ location_1 │
# ├────────────────┼────────────┼────────────┼────────────┼────────────┤
# │ cost           │ cost_0     │ cost_1     │ cost_0     │ cost_1     │
# ├────────────────┼────────────┼────────────┼────────────┼────────────┤
# │ no_of_people_0 │ 0.6        │ 0.8        │ 0.1        │ 0.6        │
# ├────────────────┼────────────┼────────────┼────────────┼────────────┤
# │ no_of_people_1 │ 0.4        │ 0.2        │ 0.9        │ 0.4        │
# ╘════════════════╧════════════╧════════════╧════════════╧════════════╛

# %% [markdown]
# #### Multiply all CPDs to obtain another CPD
# Is like a joint proba (since we have all the variables): gives the cost (first multiplied variable) **GIVEN** the other variables

# %%
joint_cpd = cpd_cost * cpd_location * cpd_quality * cpd_no_of_people
print(joint_cpd)
joint_cpd
# Out:
# ╒══════════════╤═════════════════════╤════════════════╤════════════════╤════════════════╤═════════════════════╤═══════════════════════╤══════════════════════╤══════════════════════╤═════════════════════╤═════════════════════╤════════════════════════╤═══════════════════════╕
# │ location     │ location_0          │ location_0     │ location_0     │ location_0     │ location_0          │ location_0            │ location_1           │ location_1           │ location_1          │ location_1          │ location_1             │ location_1            │
# ├──────────────┼─────────────────────┼────────────────┼────────────────┼────────────────┼─────────────────────┼───────────────────────┼──────────────────────┼──────────────────────┼─────────────────────┼─────────────────────┼────────────────────────┼───────────────────────┤
# │ quality      │ quality_0           │ quality_0      │ quality_1      │ quality_1      │ quality_2           │ quality_2             │ quality_0            │ quality_0            │ quality_1           │ quality_1           │ quality_2              │ quality_2             │
# ├──────────────┼─────────────────────┼────────────────┼────────────────┼────────────────┼─────────────────────┼───────────────────────┼──────────────────────┼──────────────────────┼─────────────────────┼─────────────────────┼────────────────────────┼───────────────────────┤
# │ no_of_people │ no_of_people_0      │ no_of_people_1 │ no_of_people_0 │ no_of_people_1 │ no_of_people_0      │ no_of_people_1        │ no_of_people_0       │ no_of_people_1       │ no_of_people_0      │ no_of_people_1      │ no_of_people_0         │ no_of_people_1        │
# ├──────────────┼─────────────────────┼────────────────┼────────────────┼────────────────┼─────────────────────┼───────────────────────┼──────────────────────┼──────────────────────┼─────────────────────┼─────────────────────┼────────────────────────┼───────────────────────┤
# │ cost_0       │ 0.08639999999999999 │ 0.0576         │ 0.108          │ 0.072          │ 0.0072              │ 0.0048000000000000004 │ 0.0072               │ 0.0648               │ 0.012               │ 0.108               │ 0.00040000000000000013 │ 0.0036000000000000008 │
# ├──────────────┼─────────────────────┼────────────────┼────────────────┼────────────────┼─────────────────────┼───────────────────────┼──────────────────────┼──────────────────────┼─────────────────────┼─────────────────────┼────────────────────────┼───────────────────────┤
# │ cost_1       │ 0.0288              │ 0.0072         │ 0.096          │ 0.024          │ 0.08640000000000002 │ 0.021600000000000005  │ 0.028800000000000003 │ 0.019200000000000005 │ 0.04800000000000001 │ 0.03200000000000001 │ 0.04560000000000001    │ 0.030400000000000007  │
# ╘══════════════╧═════════════════════╧════════════════╧════════════════╧════════════════╧═════════════════════╧═══════════════════════╧══════════════════════╧══════════════════════╧═════════════════════╧═════════════════════╧════════════════════════╧═══════════════════════╛
# <TabularCPD representing P(cost:2 | location:2, quality:3, no_of_people:2) at 0x1da3c8d2a90>

# %% [markdown]
# #### Marginalize location and quality and observe remaining conditional probabilities
# Gives cost **GIVEN** no_of_people

# %%
print(joint_cpd.marginalize(['location', 'quality'], inplace=False))
# Out:
# ╒══════════════╤═════════════════════╤═════════════════════╕
# │ no_of_people │ no_of_people_0      │ no_of_people_1      │
# ├──────────────┼─────────────────────┼─────────────────────┤
# │ cost_0       │ 0.39870223503965396 │ 0.6981132075471698  │
# ├──────────────┼─────────────────────┼─────────────────────┤
# │ cost_1       │ 0.601297764960346   │ 0.30188679245283023 │
# ╘══════════════╧═════════════════════╧═════════════════════╛

# %% [markdown]
# #### Complies with theoretical probabilities (generated with Samiam):
# ![probabilities](3_c_samiam.png)

# %% [markdown]
# #### Obtain Joint probability by converting to a Factor

# %%
joint_factor = joint_cpd.to_factor()
print(joint_factor)
joint_factor
# Out:
# ╒════════╤════════════╤═══════════╤════════════════╤═══════════════════════════════════════════╕
# │ cost   │ location   │ quality   │ no_of_people   │   phi(cost,location,quality,no_of_people) │
# ╞════════╪════════════╪═══════════╪════════════════╪═══════════════════════════════════════════╡
# │ cost_0 │ location_0 │ quality_0 │ no_of_people_0 │                                    0.0864 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_0 │ location_0 │ quality_0 │ no_of_people_1 │                                    0.0576 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_0 │ location_0 │ quality_1 │ no_of_people_0 │                                    0.1080 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_0 │ location_0 │ quality_1 │ no_of_people_1 │                                    0.0720 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_0 │ location_0 │ quality_2 │ no_of_people_0 │                                    0.0072 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_0 │ location_0 │ quality_2 │ no_of_people_1 │                                    0.0048 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_0 │ location_1 │ quality_0 │ no_of_people_0 │                                    0.0072 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_0 │ location_1 │ quality_0 │ no_of_people_1 │                                    0.0648 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_0 │ location_1 │ quality_1 │ no_of_people_0 │                                    0.0120 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_0 │ location_1 │ quality_1 │ no_of_people_1 │                                    0.1080 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_0 │ location_1 │ quality_2 │ no_of_people_0 │                                    0.0004 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_0 │ location_1 │ quality_2 │ no_of_people_1 │                                    0.0036 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_1 │ location_0 │ quality_0 │ no_of_people_0 │                                    0.0288 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_1 │ location_0 │ quality_0 │ no_of_people_1 │                                    0.0072 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_1 │ location_0 │ quality_1 │ no_of_people_0 │                                    0.0960 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_1 │ location_0 │ quality_1 │ no_of_people_1 │                                    0.0240 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_1 │ location_0 │ quality_2 │ no_of_people_0 │                                    0.0864 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_1 │ location_0 │ quality_2 │ no_of_people_1 │                                    0.0216 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_1 │ location_1 │ quality_0 │ no_of_people_0 │                                    0.0288 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_1 │ location_1 │ quality_0 │ no_of_people_1 │                                    0.0192 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_1 │ location_1 │ quality_1 │ no_of_people_0 │                                    0.0480 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_1 │ location_1 │ quality_1 │ no_of_people_1 │                                    0.0320 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_1 │ location_1 │ quality_2 │ no_of_people_0 │                                    0.0456 │
# ├────────┼────────────┼───────────┼────────────────┼───────────────────────────────────────────┤
# │ cost_1 │ location_1 │ quality_2 │ no_of_people_1 │                                    0.0304 │
# ╘════════╧════════════╧═══════════╧════════════════╧═══════════════════════════════════════════╛
# <DiscreteFactor representing phi(cost:2, location:2, quality:3, no_of_people:2) at 0x1da3c8d23c8>

# %% [markdown]
# #### Marginalize location and quality and observe remaining joint probabilities
# This is **joint** probabilities (contrast to above conditional probabilities). Joint probas sum to 1.

# %%
print(joint_factor.marginalize(['location', 'quality'], inplace=False))
# Out:
# ╒════════╤════════════════╤══════════════════════════╕
# │ cost   │ no_of_people   │   phi(cost,no_of_people) │
# ╞════════╪════════════════╪══════════════════════════╡
# │ cost_0 │ no_of_people_0 │                   0.2212 │
# ├────────┼────────────────┼──────────────────────────┤
# │ cost_0 │ no_of_people_1 │                   0.3108 │
# ├────────┼────────────────┼──────────────────────────┤
# │ cost_1 │ no_of_people_0 │                   0.3336 │
# ├────────┼────────────────┼──────────────────────────┤
# │ cost_1 │ no_of_people_1 │                   0.1344 │
# ╘════════╧════════════════╧══════════════════════════╛

# %% [markdown]
# #### Factor reduction: focus on quality=0 (good) and location=0 (good)
# This is **joint** probabilities for good quality and good location

# %%
reduced_factor=joint_factor.reduce([('quality',0), ('location',0)], inplace=False).normalize(inplace=False)
print(reduced_factor)
# Out:
# ╒════════╤════════════════╤══════════════════════════╕
# │ cost   │ no_of_people   │   phi(cost,no_of_people) │
# ╞════════╪════════════════╪══════════════════════════╡
# │ cost_0 │ no_of_people_0 │                   0.4800 │
# ├────────┼────────────────┼──────────────────────────┤
# │ cost_0 │ no_of_people_1 │                   0.3200 │
# ├────────┼────────────────┼──────────────────────────┤
# │ cost_1 │ no_of_people_0 │                   0.1600 │
# ├────────┼────────────────┼──────────────────────────┤
# │ cost_1 │ no_of_people_1 │                   0.0400 │
# ╘════════╧════════════════╧══════════════════════════╛

# %% [markdown]
# #### Marginalize no_of_people to get the proba(cost | good quality, good location)
#
# $$ P(cost\ |\ location=0, quality=0)$$
#
#
# #### and marginalize cost to get the proba(no_of_people | good quality, good location)
#
# $$ P(no\_of\_people\ |\ location=0, quality=0)$$

# %%
print(reduced_factor.marginalize(['no_of_people'], inplace=False))
print(reduced_factor.marginalize(['cost'], inplace=False))
# Out:
# ╒════════╤═════════════╕
# │ cost   │   phi(cost) │
# ╞════════╪═════════════╡
# │ cost_0 │      0.8000 │
# ├────────┼─────────────┤
# │ cost_1 │      0.2000 │
# ╘════════╧═════════════╛
# ╒════════════════╤═════════════════════╕
# │ no_of_people   │   phi(no_of_people) │
# ╞════════════════╪═════════════════════╡
# │ no_of_people_0 │              0.6400 │
# ├────────────────┼─────────────────────┤
# │ no_of_people_1 │              0.3600 │
# ╘════════════════╧═════════════════════╛

# %% [markdown]
# #### Complies with theoretical probabilities  (generated with Samiam):
# ![probabilities](3_d_samiam.png)

# %% [markdown]
# ##  Inference : using Variable Elimination Algorithm
# #### Use Inference to compute the above conditional probability
# $$ P(cost\ |\ location=0, quality=0)$$ and $$ P(no\_of\_people\ |\ location=0, quality=0)$$

# %%
restaurant_inference = VariableElimination(restaurant)
inferred=restaurant_inference.query(variables=['cost', 'no_of_people'],
                           evidence={'location': 0, 'quality': 0})
print(inferred['cost'])
print(inferred['no_of_people'])
# Out:
# ╒════════╤═════════════╕
# │ cost   │   phi(cost) │
# ╞════════╪═════════════╡
# │ cost_0 │      0.8000 │
# ├────────┼─────────────┤
# │ cost_1 │      0.2000 │
# ╘════════╧═════════════╛
# ╒════════════════╤═════════════════════╕
# │ no_of_people   │   phi(no_of_people) │
# ╞════════════════╪═════════════════════╡
# │ no_of_people_0 │              0.6400 │
# ├────────────────┼─────────────────────┤
# │ no_of_people_1 │              0.3600 │
# ╘════════════════╧═════════════════════╛

# %% [markdown]
# #### JointProbabilityDistribution
# Like TabularCPD, JointProbabilityDistribution is a DiscreteFactor that is created from joint probabilities

# %%
from pgmpy.factors.discrete import JointProbabilityDistribution as JPD
joint_dist = JPD(['I','D','G'],[2,2,3], [0.126,0.168,0.126,0.009,0.045,0.126,0.252,0.0224,0.0056,0.06,0.036,0.024])
print(joint_dist)
# Out:
# ╒═════╤═════╤═════╤════════════╕
# │ I   │ D   │ G   │   P(I,D,G) │
# ╞═════╪═════╪═════╪════════════╡
# │ I_0 │ D_0 │ G_0 │     0.1260 │
# ├─────┼─────┼─────┼────────────┤
# │ I_0 │ D_0 │ G_1 │     0.1680 │
# ├─────┼─────┼─────┼────────────┤
# │ I_0 │ D_0 │ G_2 │     0.1260 │
# ├─────┼─────┼─────┼────────────┤
# │ I_0 │ D_1 │ G_0 │     0.0090 │
# ├─────┼─────┼─────┼────────────┤
# │ I_0 │ D_1 │ G_1 │     0.0450 │
# ├─────┼─────┼─────┼────────────┤
# │ I_0 │ D_1 │ G_2 │     0.1260 │
# ├─────┼─────┼─────┼────────────┤
# │ I_1 │ D_0 │ G_0 │     0.2520 │
# ├─────┼─────┼─────┼────────────┤
# │ I_1 │ D_0 │ G_1 │     0.0224 │
# ├─────┼─────┼─────┼────────────┤
# │ I_1 │ D_0 │ G_2 │     0.0056 │
# ├─────┼─────┼─────┼────────────┤
# │ I_1 │ D_1 │ G_0 │     0.0600 │
# ├─────┼─────┼─────┼────────────┤
# │ I_1 │ D_1 │ G_1 │     0.0360 │
# ├─────┼─────┼─────┼────────────┤
# │ I_1 │ D_1 │ G_2 │     0.0240 │
# ╘═════╧═════╧═════╧════════════╛

# %% [markdown]
# Reduce a JointProbabilityDistribution to focus on some observations

# %%
print(joint_dist.reduce([('G', 0)], inplace=False))
# Out:
# ╒═════╤═════╤══════════╕
# │ I   │ D   │   P(I,D) │
# ╞═════╪═════╪══════════╡
# │ I_0 │ D_0 │   0.1260 │
# ├─────┼─────┼──────────┤
# │ I_0 │ D_1 │   0.0090 │
# ├─────┼─────┼──────────┤
# │ I_1 │ D_0 │   0.2520 │
# ├─────┼─────┼──────────┤
# │ I_1 │ D_1 │   0.0600 │
# ╘═════╧═════╧══════════╛

# %% [markdown]
# or marginalize some variables to get probas on remaining variables

# %%
joint_dist.marginalize(['D'])
print(joint_dist)
# Out:
# ╒═════╤═════╤══════════╕
# │ I   │ G   │   P(I,G) │
# ╞═════╪═════╪══════════╡
# │ I_0 │ G_0 │   0.1350 │
# ├─────┼─────┼──────────┤
# │ I_0 │ G_1 │   0.2130 │
# ├─────┼─────┼──────────┤
# │ I_0 │ G_2 │   0.2520 │
# ├─────┼─────┼──────────┤
# │ I_1 │ G_0 │   0.3120 │
# ├─────┼─────┼──────────┤
# │ I_1 │ G_1 │   0.0584 │
# ├─────┼─────┼──────────┤
# │ I_1 │ G_2 │   0.0296 │
# ╘═════╧═════╧══════════╛

# %% [markdown]
# ## Sampling
# #### Sample some data from the model with some evidence
# First try with rejection_sample sampler (computationally expensive)

# %%
from pgmpy.sampling.Sampling import BayesianModelSampling
sampler = BayesianModelSampling(restaurant)

# e.g. location=1 (bad) and cost=0 (high) should yield a P(no_people=1 (low people)) that is high
from pgmpy.factors.discrete import State
evidence = [State('location', 1), State('cost', 0)]
df=sampler.rejection_sample(evidence=evidence, size=500)
df[:5]
# Out:
#    location  quality  cost  no_of_people
# 0         1        0     0             1
# 1         1        1     0             1
# 2         1        1     0             1
# 3         1        1     0             1
# 4         1        0     0             1

# %%
p_people_0=len(df[df.no_of_people==0]) / float(len(df))
print('P(no_of_people=0|location=1,cost=0): %.5f' % p_people_0)

p_quality_0=len(df[df.quality==0]) / float(len(df))
print('P(quality=0|location=1,cost=0): %.5f' % p_quality_0)
# Out:
# P(no_of_people=0|location=1,cost=0): 0.09200
# P(quality=0|location=1,cost=0): 0.35400

# %% [markdown]
# #### Complies with theoretical probabilities  (generated with Samiam):
# ![probabilities](3_a_samiam.png)

# %% [markdown]
# Next try likelihood_weighted_sample (with evidence)

# %%
df=sampler.likelihood_weighted_sample(evidence=evidence, size=20000)
df=df.loc[:,df.columns[:-1]]
df[:5]
# Out:
#    location  quality  cost  no_of_people
# 0         1        1     0             1
# 1         1        1     0             0
# 2         1        0     0             1
# 3         1        0     0             1
# 4         1        1     0             1

# %%
p_people_0=len(df[df.no_of_people==0]) / float(len(df))
print('P(no_of_people=0|location=1,cost=0): %.5f' % p_people_0)

p_quality_0=len(df[df.quality==0]) / float(len(df))
print('P(quality=0|location=1,cost=0): %.5f' % p_quality_0)
# Out:
# P(no_of_people=0|location=1,cost=0): 0.09990
# P(quality=0|location=1,cost=0): 0.29695

# %% [markdown]
# #### Sample some Data from the model (no evidence)
# Gibbs Sampling (without evidence)

# %%
from pgmpy.sampling.Sampling import GibbsSampling
gibbs_sampler = GibbsSampling(restaurant)
df=gibbs_sampler.sample(size=5000)
df[:5]
# Out:
#    quality  no_of_people  cost  location
# 0        1             1     0         0
# 1        0             0     1         1
# 2        1             1     0         0
# 3        1             1     1         0
# 4        1             0     0         0

# %%
p_people_0=len(df[df.no_of_people==0]) / float(len(df))
print('P(no_of_people=0): %.5f' % p_people_0)

p_quality_0=len(df[df.quality==0]) / float(len(df))
print('P(quality=0): %.5f' % p_quality_0)
# Out:
# P(no_of_people=0): 0.55140
# P(quality=0): 0.30060

# %% [markdown]
# Forwarder sampling (without evidence)

# %%
df=sampler.forward_sample(size=50000)
df[:5]
# Out:
#    location  quality  cost  no_of_people
# 0         1        1     0             1
# 1         1        1     1             0
# 2         0        0     1             0
# 3         0        1     0             1
# 4         1        1     0             1

# %% [markdown]
# **Verify** $$ P(no\_of\_people\ |\ location=0, quality=2)$$

# %%
p_quality_2=len(df[df.quality==2])
p_people_0_quality_2=len(df[(df.quality==2) & (df.no_of_people==0)])
p_people_0_given_quality_2 = p_people_0_quality_2 / float(p_quality_2)
print('P(people=0|quality=2): %.5f' % p_people_0_given_quality_2)
# Out:
# P(people=0|quality=2): 0.69679

# %% [markdown]
# #### Complies with theoretical probabilities (generated with Samiam):
# ![probabilities](3_b_samiam.png)

# %% [markdown]
# ## Structure Learning
# ### Estimate Structure with HillClimbSearch

# %%
from pgmpy.estimators import HillClimbSearch, BicScore,BdeuScore,K2Score

# %%
est = HillClimbSearch(df, scoring_method=BicScore(df))
best_model = est.estimate()
print('nodes: ' + str(best_model.nodes()))
print('edges: ' + str(best_model.edges()))
# Out:
# nodes: ['quality', 'no_of_people', 'cost', 'location']
# edges: [('quality', 'cost'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'cost')]

# %%
est = HillClimbSearch(df, scoring_method=BdeuScore(df))
best_model = est.estimate()
print('nodes: ' + str(best_model.nodes()))
print('edges: ' + str(best_model.edges()))
# Out:
# nodes: ['quality', 'no_of_people', 'cost', 'location']
# edges: [('quality', 'cost'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'cost')]

# %%
est = HillClimbSearch(df, scoring_method=K2Score(df))
best_model = est.estimate()
print('nodes: ' + str(best_model.nodes()))
print('edges: ' + str(best_model.edges()))
# Out:
# nodes: ['quality', 'no_of_people', 'cost', 'location']
# edges: [('quality', 'cost'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'cost')]

# %% [markdown]
# ### Estimate Structure with ExhaustiveSearch

# %%
import pandas as pd
from pgmpy.estimators import ExhaustiveSearch
df = pd.DataFrame(data=df)
s = ExhaustiveSearch(df)
df
# Out:
#        location  quality  cost  no_of_people
# 0             1        1     0             1
# 1             1        1     1             0
# 2             0        0     1             0
# 3             0        1     0             1
# 4             1        1     0             1
# 5             0        0     0             1
# 6             0        0     0             1
# 7             0        0     1             0
# 8             0        2     1             0
# 9             0        1     1             0
# 10            1        1     0             1
# 11            1        0     0             1
# 12            0        1     0             0
# 13            0        0     0             0
# 14            0        1     1             0
# 15            0        1     0             0
# 16            1        1     0             1
# 17            0        0     0             1
# 18            0        0     0             0
# 19            1        1     1             0
# 20            0        1     0             0
# 21            0        1     0             1
# 22            1        2     1             1
# 23            0        0     0             1
# 24            1        1     0             1
# 25            0        1     0             0
# 26            1        1     0             0
# 27            1        1     1             1
# 28            0        2     0             0
# 29            0        0     0             1
# ...         ...      ...   ...           ...
# 49970         1        2     1             0
# 49971         0        1     0             0
# 49972         0        1     0             0
# 49973         1        2     0             1
# 49974         1        1     0             1
# 49975         1        1     0             1
# 49976         1        0     1             0
# 49977         0        1     0             0
# 49978         1        1     0             1
# 49979         0        1     1             0
# 49980         0        2     1             1
# 49981         1        2     0             1
# 49982         0        1     0             0
# 49983         1        1     1             1
# 49984         0        1     1             1
# 49985         1        0     1             0
# 49986         1        1     0             1
# 49987         0        1     0             1
# 49988         0        2     1             0
# 49989         0        2     0             1
# 49990         1        1     0             1
# 49991         1        1     0             1
# 49992         1        1     0             1
# 49993         1        2     1             1
# 49994         0        1     0             0
# 49995         1        2     1             0
# 49996         0        1     0             0
# 49997         0        0     0             0
# 49998         0        1     1             1
# 49999         0        1     1             0
#
# [50000 rows x 4 columns]

# %%
s = ExhaustiveSearch(df, scoring_method=BicScore(df))
for score, model in s.all_scores():
    print("{0}        {1}".format(score, model.edges()))
# Out:
# -154203.24119922565        [('location', 'quality')]
# -154203.24119922565        [('quality', 'location')]
# -154192.9573184981        []
# -154099.13740838305        [('cost', 'location'), ('location', 'quality')]
# -154099.13740838305        [('quality', 'location'), ('location', 'cost')]
# -154099.13740838302        [('location', 'quality'), ('location', 'cost')]
# -154088.8535276555        [('cost', 'location')]
# -154088.85352765548        [('location', 'cost')]
# -153820.72454230138        [('quality', 'location'), ('cost', 'location')]
# -153677.2406927543        [('no_of_people', 'quality'), ('quality', 'location')]
# -153677.2406927543        [('quality', 'no_of_people'), ('quality', 'location')]
# -153677.24069275428        [('quality', 'no_of_people'), ('location', 'quality')]
# -153666.95681202674        [('no_of_people', 'quality')]
# -153666.95681202674        [('quality', 'no_of_people')]
# -153573.1369019117        [('quality', 'no_of_people'), ('cost', 'location'), ('location', 'quality')]
# -153573.1369019117        [('quality', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -153573.1369019117        [('no_of_people', 'quality'), ('quality', 'location'), ('location', 'cost')]
# -153573.1369019117        [('quality', 'no_of_people'), ('quality', 'location'), ('location', 'cost')]
# -153562.85302118416        [('no_of_people', 'quality'), ('cost', 'location')]
# -153562.85302118416        [('quality', 'no_of_people'), ('cost', 'location')]
# -153562.85302118416        [('no_of_people', 'quality'), ('location', 'cost')]
# -153562.85302118416        [('quality', 'no_of_people'), ('location', 'cost')]
# -153530.52116513462        [('no_of_people', 'quality'), ('location', 'quality')]
# -153426.417374292        [('no_of_people', 'quality'), ('cost', 'location'), ('location', 'quality')]
# -153426.41737429198        [('no_of_people', 'quality'), ('location', 'quality'), ('location', 'cost')]
# -153294.72403583003        [('no_of_people', 'quality'), ('quality', 'location'), ('cost', 'location')]
# -153294.72403583003        [('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'location')]
# -151931.27572565555        [('cost', 'no_of_people'), ('location', 'quality')]
# -151931.27572565555        [('quality', 'location'), ('cost', 'no_of_people')]
# -151931.27572565555        [('no_of_people', 'cost'), ('location', 'quality')]
# -151931.27572565555        [('no_of_people', 'cost'), ('quality', 'location')]
# -151920.991844928        [('cost', 'no_of_people')]
# -151920.991844928        [('no_of_people', 'cost')]
# -151916.44258981195        [('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'no_of_people')]
# -151916.44258981192        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('location', 'quality')]
# -151906.15870908438        [('quality', 'no_of_people'), ('cost', 'no_of_people')]
# -151827.17193481297        [('cost', 'no_of_people'), ('cost', 'location'), ('location', 'quality')]
# -151827.17193481297        [('no_of_people', 'cost'), ('cost', 'location'), ('location', 'quality')]
# -151827.17193481297        [('cost', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -151827.17193481297        [('quality', 'location'), ('cost', 'no_of_people'), ('location', 'cost')]
# -151816.88805408543        [('no_of_people', 'cost'), ('cost', 'location')]
# -151816.8880540854        [('cost', 'no_of_people'), ('cost', 'location')]
# -151816.8880540854        [('cost', 'no_of_people'), ('location', 'cost')]
# -151812.33879896934        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'location'), ('location', 'quality')]
# -151812.33879896934        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -151812.33879896934        [('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'no_of_people'), ('location', 'cost')]
# -151802.0549182418        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'location')]
# -151802.0549182418        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('location', 'cost')]
# -151548.75906873128        [('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'location')]
# -151548.75906873128        [('no_of_people', 'cost'), ('quality', 'location'), ('cost', 'location')]
# -151533.92593288768        [('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'location')]
# -151405.27521918423        [('no_of_people', 'quality'), ('quality', 'location'), ('cost', 'no_of_people')]
# -151405.27521918423        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('quality', 'location')]
# -151405.27521918423        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'location')]
# -151405.2752191842        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('location', 'quality')]
# -151394.9913384567        [('no_of_people', 'quality'), ('cost', 'no_of_people')]
# -151394.99133845666        [('no_of_people', 'quality'), ('no_of_people', 'cost')]
# -151394.99133845666        [('no_of_people', 'cost'), ('quality', 'no_of_people')]
# -151393.2015724398        [('location', 'no_of_people'), ('location', 'quality')]
# -151393.2015724398        [('quality', 'location'), ('location', 'no_of_people')]
# -151393.2015724398        [('no_of_people', 'location'), ('location', 'quality')]
# -151382.91769171227        [('location', 'no_of_people')]
# -151382.91769171227        [('no_of_people', 'location')]
# -151290.88754761408        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('cost', 'location')]
# -151290.88754761405        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('cost', 'location')]
# -151290.88754761405        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('cost', 'location')]
# -151290.88754761405        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('location', 'cost')]
# -151289.09778159723        [('quality', 'location'), ('location', 'no_of_people'), ('location', 'cost')]
# -151289.0977815972        [('cost', 'location'), ('location', 'no_of_people'), ('location', 'quality')]
# -151289.0977815972        [('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -151289.0977815972        [('no_of_people', 'location'), ('location', 'quality'), ('location', 'cost')]
# -151278.81390086966        [('cost', 'location'), ('location', 'no_of_people')]
# -151278.81390086966        [('location', 'no_of_people'), ('location', 'cost')]
# -151278.81390086966        [('no_of_people', 'location'), ('location', 'cost')]
# -151258.5556915645        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('location', 'quality')]
# -151258.5556915645        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('location', 'quality')]
# -151246.48204482012        [('no_of_people', 'location'), ('quality', 'location')]
# -151154.45190072194        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('cost', 'location'), ('location', 'quality')]
# -151154.45190072194        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('cost', 'location'), ('location', 'quality')]
# -151154.45190072194        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -151142.3782539775        [('no_of_people', 'location'), ('quality', 'location'), ('location', 'cost')]
# -151022.75856225996        [('no_of_people', 'quality'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'location')]
# -151022.75856225993        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('quality', 'location'), ('cost', 'location')]
# -151022.75856225993        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'location')]
# -151010.68491551554        [('quality', 'location'), ('cost', 'location'), ('location', 'no_of_people')]
# -150856.91718524092        [('no_of_people', 'quality'), ('no_of_people', 'location')]
# -150856.91718524092        [('no_of_people', 'location'), ('quality', 'no_of_people')]
# -150856.9171852409        [('no_of_people', 'quality'), ('location', 'no_of_people')]
# -150752.8133943983        [('no_of_people', 'quality'), ('cost', 'location'), ('location', 'no_of_people')]
# -150752.8133943983        [('no_of_people', 'quality'), ('location', 'no_of_people'), ('location', 'cost')]
# -150752.8133943983        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('location', 'cost')]
# -150752.8133943983        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('location', 'cost')]
# -150720.48153834877        [('no_of_people', 'quality'), ('location', 'no_of_people'), ('location', 'quality')]
# -150720.48153834877        [('quality', 'no_of_people'), ('location', 'no_of_people'), ('location', 'quality')]
# -150720.48153834877        [('quality', 'no_of_people'), ('quality', 'location'), ('location', 'no_of_people')]
# -150720.48153834877        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('location', 'quality')]
# -150720.48153834877        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('quality', 'location')]
# -150720.48153834877        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'location')]
# -150710.19765762123        [('quality', 'no_of_people'), ('location', 'no_of_people')]
# -150616.3777475062        [('quality', 'no_of_people'), ('quality', 'location'), ('location', 'no_of_people'), ('location', 'cost')]
# -150616.37774750617        [('no_of_people', 'quality'), ('cost', 'location'), ('location', 'no_of_people'), ('location', 'quality')]
# -150616.37774750617        [('quality', 'no_of_people'), ('cost', 'location'), ('location', 'no_of_people'), ('location', 'quality')]
# -150616.37774750617        [('no_of_people', 'quality'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -150616.37774750617        [('quality', 'no_of_people'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -150616.37774750617        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('location', 'quality'), ('location', 'cost')]
# -150616.37774750617        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('quality', 'location'), ('location', 'cost')]
# -150616.37774750617        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'location'), ('location', 'cost')]
# -150606.09386677862        [('quality', 'no_of_people'), ('cost', 'location'), ('location', 'no_of_people')]
# -150606.09386677862        [('quality', 'no_of_people'), ('location', 'no_of_people'), ('location', 'cost')]
# -150391.70655134384        [('no_of_people', 'cost'), ('location', 'quality'), ('location', 'cost')]
# -150391.70655134384        [('no_of_people', 'cost'), ('quality', 'location'), ('location', 'cost')]
# -150381.4226706163        [('no_of_people', 'cost'), ('location', 'cost')]
# -150337.9648814245        [('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'location'), ('location', 'no_of_people')]
# -149865.7060448725        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('quality', 'location'), ('location', 'cost')]
# -149865.7060448725        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'location'), ('location', 'cost')]
# -149865.70604487247        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -149855.42216414493        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('location', 'cost')]
# -149855.42216414493        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('location', 'cost')]
# -149853.6323981281        [('no_of_people', 'location'), ('cost', 'location'), ('location', 'quality')]
# -149843.34851740056        [('no_of_people', 'location'), ('cost', 'location')]
# -149718.9865172528        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('location', 'quality'), ('location', 'cost')]
# -149628.55195006437        [('no_of_people', 'location'), ('quality', 'location'), ('cost', 'location')]
# -149317.3480109292        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('cost', 'location')]
# -149317.3480109292        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('cost', 'location')]
# -149180.91236403707        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('cost', 'location'), ('location', 'quality')]
# -149121.23609886973        [('no_of_people', 'location'), ('cost', 'no_of_people'), ('location', 'quality')]
# -149121.23609886973        [('no_of_people', 'cost'), ('quality', 'location'), ('location', 'no_of_people')]
# -149121.23609886973        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('location', 'quality')]
# -149121.2360988697        [('no_of_people', 'cost'), ('location', 'no_of_people'), ('location', 'quality')]
# -149110.9522181422        [('no_of_people', 'cost'), ('no_of_people', 'location')]
# -149110.95221814216        [('no_of_people', 'location'), ('cost', 'no_of_people')]
# -149110.95221814216        [('no_of_people', 'cost'), ('location', 'no_of_people')]
# -149102.55144359302        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('quality', 'location'), ('cost', 'location')]
# -149102.55144359302        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'location')]
# -149096.11908229857        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('cost', 'no_of_people')]
# -148974.51657125005        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'location')]
# -148974.51657125002        [('no_of_people', 'location'), ('quality', 'location'), ('cost', 'no_of_people')]
# -148959.68343540642        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'no_of_people')]
# -148584.95171167084        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('cost', 'no_of_people')]
# -148584.95171167084        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('location', 'no_of_people')]
# -148584.95171167084        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location')]
# -148584.95171167084        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'no_of_people')]
# -148448.5160647787        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('cost', 'no_of_people'), ('location', 'quality')]
# -148448.5160647787        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('quality', 'location'), ('cost', 'no_of_people')]
# -148448.5160647787        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'location'), ('location', 'no_of_people')]
# -148448.5160647787        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('location', 'quality')]
# -148448.5160647787        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'location')]
# -148448.5160647787        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'location')]
# -148448.51606477867        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('location', 'no_of_people'), ('location', 'quality')]
# -148448.51606477867        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('location', 'no_of_people'), ('location', 'quality')]
# -148438.23218405113        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('location', 'no_of_people')]
# -148224.06369823896        [('quality', 'location'), ('cost', 'quality')]
# -148224.06369823893        [('quality', 'cost'), ('location', 'quality')]
# -148224.06369823893        [('quality', 'cost'), ('quality', 'location')]
# -148213.7798175114        [('cost', 'quality')]
# -148213.7798175114        [('quality', 'cost')]
# -148209.23056239536        [('no_of_people', 'quality'), ('quality', 'location'), ('cost', 'quality')]
# -148198.94668166782        [('no_of_people', 'quality'), ('cost', 'quality')]
# -148109.6760266688        [('cost', 'quality'), ('cost', 'location')]
# -148109.6760266688        [('quality', 'cost'), ('cost', 'location')]
# -148109.6760266688        [('cost', 'quality'), ('location', 'cost')]
# -148094.8428908252        [('no_of_people', 'quality'), ('cost', 'quality'), ('cost', 'location')]
# -148094.84289082518        [('no_of_people', 'quality'), ('cost', 'quality'), ('location', 'cost')]
# -147984.15011433163        [('no_of_people', 'quality'), ('cost', 'quality'), ('location', 'quality')]
# -147945.6508321573        [('cost', 'quality'), ('location', 'quality')]
# -147880.04632348902        [('no_of_people', 'quality'), ('cost', 'quality'), ('cost', 'location'), ('location', 'quality')]
# -147880.046323489        [('no_of_people', 'quality'), ('cost', 'quality'), ('location', 'quality'), ('location', 'cost')]
# -147841.54704131468        [('cost', 'quality'), ('cost', 'location'), ('location', 'quality')]
# -147841.54704131468        [('quality', 'location'), ('cost', 'quality'), ('cost', 'location')]
# -147841.54704131468        [('quality', 'cost'), ('quality', 'location'), ('location', 'cost')]
# -147841.54704131465        [('quality', 'cost'), ('quality', 'location'), ('cost', 'location')]
# -147841.54704131465        [('cost', 'quality'), ('location', 'quality'), ('location', 'cost')]
# -147841.54704131465        [('quality', 'cost'), ('location', 'quality'), ('location', 'cost')]
# -147831.2631605871        [('quality', 'cost'), ('location', 'cost')]
# -147826.7139054711        [('no_of_people', 'quality'), ('quality', 'location'), ('cost', 'quality'), ('cost', 'location')]
# -147724.26999757497        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'quality')]
# -147724.26999757494        [('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'no_of_people'), ('location', 'no_of_people')]
# -147713.98611684737        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('location', 'no_of_people')]
# -147698.0631917676        [('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'quality')]
# -147698.0631917676        [('no_of_people', 'quality'), ('quality', 'cost'), ('quality', 'location')]
# -147698.0631917676        [('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location')]
# -147698.06319176758        [('quality', 'no_of_people'), ('quality', 'cost'), ('location', 'quality')]
# -147687.77931104007        [('quality', 'no_of_people'), ('cost', 'quality')]
# -147687.77931104004        [('no_of_people', 'quality'), ('quality', 'cost')]
# -147687.77931104004        [('quality', 'no_of_people'), ('quality', 'cost')]
# -147685.7707154006        [('quality', 'location'), ('cost', 'no_of_people'), ('location', 'no_of_people')]
# -147685.77071540058        [('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'quality')]
# -147675.48683467304        [('cost', 'no_of_people'), ('location', 'no_of_people')]
# -147620.16620673236        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'location'), ('location', 'no_of_people'), ('location', 'quality')]
# -147620.16620673233        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -147620.16620673233        [('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'cost')]
# -147609.8823260048        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'location'), ('location', 'no_of_people')]
# -147609.8823260048        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'cost')]
# -147583.67552019746        [('quality', 'no_of_people'), ('cost', 'quality'), ('cost', 'location')]
# -147583.67552019743        [('no_of_people', 'quality'), ('quality', 'cost'), ('cost', 'location')]
# -147583.67552019743        [('quality', 'no_of_people'), ('quality', 'cost'), ('cost', 'location')]
# -147583.67552019743        [('quality', 'no_of_people'), ('cost', 'quality'), ('location', 'cost')]
# -147581.66692455803        [('no_of_people', 'location'), ('cost', 'no_of_people'), ('cost', 'location'), ('location', 'quality')]
# -147581.666924558        [('cost', 'no_of_people'), ('cost', 'location'), ('location', 'no_of_people'), ('location', 'quality')]
# -147581.666924558        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('cost', 'location'), ('location', 'quality')]
# -147581.666924558        [('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -147581.666924558        [('quality', 'location'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'cost')]
# -147581.666924558        [('no_of_people', 'cost'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -147581.666924558        [('no_of_people', 'cost'), ('quality', 'location'), ('location', 'no_of_people'), ('location', 'cost')]
# -147581.666924558        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('location', 'quality'), ('location', 'cost')]
# -147571.38304383046        [('cost', 'no_of_people'), ('cost', 'location'), ('location', 'no_of_people')]
# -147571.38304383046        [('no_of_people', 'location'), ('cost', 'no_of_people'), ('cost', 'location')]
# -147571.38304383046        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('cost', 'location')]
# -147571.38304383046        [('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'cost')]
# -147571.38304383046        [('no_of_people', 'cost'), ('location', 'no_of_people'), ('location', 'cost')]
# -147571.38304383046        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('location', 'cost')]
# -147556.54990798686        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'location')]
# -147551.3436641479        [('no_of_people', 'quality'), ('quality', 'cost'), ('location', 'quality')]
# -147434.9473969383        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'location'), ('location', 'cost')]
# -147419.6503256859        [('quality', 'no_of_people'), ('cost', 'quality'), ('location', 'quality')]
# -147356.58647649427        [('no_of_people', 'location'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'location')]
# -147356.58647649427        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'location'), ('cost', 'location')]
# -147341.75334065067        [('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'location'), ('location', 'no_of_people')]
# -147341.75334065067        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'location')]
# -147315.54653484334        [('quality', 'no_of_people'), ('cost', 'quality'), ('cost', 'location'), ('location', 'quality')]
# -147315.54653484334        [('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'quality'), ('cost', 'location')]
# -147315.54653484334        [('quality', 'no_of_people'), ('cost', 'quality'), ('location', 'quality'), ('location', 'cost')]
# -147315.54653484334        [('quality', 'no_of_people'), ('quality', 'cost'), ('location', 'quality'), ('location', 'cost')]
# -147315.54653484334        [('no_of_people', 'quality'), ('quality', 'cost'), ('quality', 'location'), ('location', 'cost')]
# -147315.54653484334        [('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('location', 'cost')]
# -147315.5465348433        [('no_of_people', 'quality'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'location')]
# -147315.5465348433        [('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'location')]
# -147305.2626541158        [('no_of_people', 'quality'), ('quality', 'cost'), ('location', 'cost')]
# -147305.2626541158        [('quality', 'no_of_people'), ('quality', 'cost'), ('location', 'cost')]
# -147303.25405847633        [('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'location'), ('location', 'no_of_people')]
# -147168.82700722362        [('no_of_people', 'quality'), ('quality', 'cost'), ('location', 'quality'), ('location', 'cost')]
# -147149.48632820172        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('location', 'no_of_people')]
# -147045.38253735914        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('cost', 'no_of_people'), ('cost', 'location')]
# -147045.3825373591        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('cost', 'location'), ('location', 'no_of_people')]
# -147045.3825373591        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('cost', 'location')]
# -147045.3825373591        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'no_of_people'), ('cost', 'location')]
# -147045.3825373591        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('location', 'cost')]
# -147045.3825373591        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'no_of_people'), ('location', 'cost')]
# -147045.38253735908        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'cost')]
# -147045.38253735908        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('location', 'no_of_people'), ('location', 'cost')]
# -147013.05068130954        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'quality')]
# -146908.946890467        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('cost', 'no_of_people'), ('cost', 'location'), ('location', 'quality')]
# -146908.94689046696        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('cost', 'location'), ('location', 'no_of_people'), ('location', 'quality')]
# -146908.94689046696        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('cost', 'location'), ('location', 'quality')]
# -146908.94689046696        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -146908.94689046696        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -146908.94689046696        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -146908.94689046696        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'location'), ('location', 'no_of_people'), ('location', 'cost')]
# -146908.94689046696        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('location', 'quality'), ('location', 'cost')]
# -146908.94689046696        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'location'), ('location', 'cost')]
# -146908.94689046696        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'location'), ('location', 'cost')]
# -146898.66300973942        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('location', 'no_of_people'), ('location', 'cost')]
# -146830.58597002295        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'location')]
# -146830.58597002295        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'location'), ('cost', 'location')]
# -146830.58597002295        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'location')]
# -146463.2655952966        [('no_of_people', 'cost'), ('quality', 'cost'), ('quality', 'location')]
# -146463.26559529657        [('no_of_people', 'cost'), ('quality', 'cost'), ('location', 'quality')]
# -146452.98171456903        [('no_of_people', 'cost'), ('quality', 'cost')]
# -146348.87792372645        [('no_of_people', 'cost'), ('quality', 'cost'), ('cost', 'location')]
# -146080.74893837233        [('no_of_people', 'cost'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'location')]
# -145952.09822466888        [('no_of_people', 'cost'), ('quality', 'location'), ('cost', 'quality')]
# -145952.09822466885        [('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'quality')]
# -145952.09822466885        [('quality', 'cost'), ('cost', 'no_of_people'), ('location', 'quality')]
# -145952.09822466885        [('quality', 'cost'), ('quality', 'location'), ('cost', 'no_of_people')]
# -145941.8143439413        [('no_of_people', 'cost'), ('cost', 'quality')]
# -145941.81434394128        [('cost', 'no_of_people'), ('cost', 'quality')]
# -145941.81434394128        [('quality', 'cost'), ('cost', 'no_of_people')]
# -145937.26508882525        [('no_of_people', 'quality'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'quality')]
# -145937.26508882525        [('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'quality')]
# -145937.26508882525        [('quality', 'no_of_people'), ('quality', 'cost'), ('cost', 'no_of_people'), ('location', 'quality')]
# -145937.26508882525        [('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'no_of_people')]
# -145937.26508882525        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('quality', 'location'), ('cost', 'quality')]
# -145937.26508882525        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'cost'), ('location', 'quality')]
# -145937.26508882525        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('quality', 'cost'), ('quality', 'location')]
# -145937.26508882525        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location')]
# -145926.9812080977        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('cost', 'quality')]
# -145926.9812080977        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'quality')]
# -145926.9812080977        [('quality', 'no_of_people'), ('quality', 'cost'), ('cost', 'no_of_people')]
# -145926.9812080977        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('cost', 'quality')]
# -145926.9812080977        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('quality', 'cost')]
# -145926.9812080977        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'cost')]
# -145837.7105530987        [('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location')]
# -145837.7105530987        [('quality', 'cost'), ('cost', 'no_of_people'), ('cost', 'location')]
# -145837.7105530987        [('no_of_people', 'cost'), ('cost', 'quality'), ('cost', 'location')]
# -145837.7105530987        [('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'cost')]
# -145822.87741725513        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('cost', 'quality'), ('cost', 'location')]
# -145822.8774172551        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location')]
# -145822.8774172551        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location')]
# -145822.8774172551        [('quality', 'no_of_people'), ('quality', 'cost'), ('cost', 'no_of_people'), ('cost', 'location')]
# -145822.8774172551        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('quality', 'cost'), ('cost', 'location')]
# -145822.8774172551        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'cost'), ('cost', 'location')]
# -145822.8774172551        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'cost')]
# -145822.8774172551        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'cost')]
# -145790.54556120554        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('quality', 'cost'), ('location', 'quality')]
# -145712.18464076152        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'quality')]
# -145712.18464076152        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('cost', 'quality'), ('location', 'quality')]
# -145673.6853585872        [('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'quality')]
# -145673.6853585872        [('no_of_people', 'cost'), ('cost', 'quality'), ('location', 'quality')]
# -145658.85222274356        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'quality')]
# -145608.08084991894        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('cost', 'quality'), ('cost', 'location'), ('location', 'quality')]
# -145608.08084991892        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location'), ('location', 'quality')]
# -145608.08084991892        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'quality'), ('location', 'cost')]
# -145569.5815677446        [('no_of_people', 'cost'), ('cost', 'quality'), ('cost', 'location'), ('location', 'quality')]
# -145569.5815677446        [('quality', 'cost'), ('cost', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -145569.58156774458        [('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location'), ('location', 'quality')]
# -145569.58156774458        [('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location')]
# -145569.58156774458        [('quality', 'cost'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'location')]
# -145569.58156774458        [('no_of_people', 'cost'), ('quality', 'location'), ('cost', 'quality'), ('cost', 'location')]
# -145569.58156774458        [('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'quality'), ('location', 'cost')]
# -145569.58156774458        [('quality', 'cost'), ('quality', 'location'), ('cost', 'no_of_people'), ('location', 'cost')]
# -145559.297687017        [('quality', 'cost'), ('cost', 'no_of_people'), ('location', 'cost')]
# -145554.74843190098        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location'), ('location', 'quality')]
# -145554.74843190098        [('no_of_people', 'quality'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location')]
# -145554.74843190098        [('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location')]
# -145554.74843190098        [('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'location')]
# -145554.74843190098        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('quality', 'location'), ('cost', 'quality'), ('cost', 'location')]
# -145554.74843190098        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'location')]
# -145554.74843190098        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'location')]
# -145554.74843190098        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'quality'), ('location', 'cost')]
# -145554.74843190098        [('quality', 'no_of_people'), ('quality', 'cost'), ('cost', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -145554.74843190098        [('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'no_of_people'), ('location', 'cost')]
# -145544.46455117344        [('quality', 'no_of_people'), ('quality', 'cost'), ('cost', 'no_of_people'), ('location', 'cost')]
# -145414.0240714531        [('quality', 'location'), ('cost', 'quality'), ('location', 'no_of_people')]
# -145414.0240714531        [('quality', 'cost'), ('quality', 'location'), ('location', 'no_of_people')]
# -145414.0240714531        [('no_of_people', 'location'), ('quality', 'cost'), ('location', 'quality')]
# -145414.02407145308        [('quality', 'cost'), ('location', 'no_of_people'), ('location', 'quality')]
# -145403.74019072557        [('no_of_people', 'location'), ('cost', 'quality')]
# -145403.74019072557        [('no_of_people', 'location'), ('quality', 'cost')]
# -145403.74019072554        [('cost', 'quality'), ('location', 'no_of_people')]
# -145403.74019072554        [('quality', 'cost'), ('location', 'no_of_people')]
# -145388.90705488197        [('no_of_people', 'quality'), ('cost', 'quality'), ('location', 'no_of_people')]
# -145388.90705488197        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('cost', 'quality')]
# -145299.63639988296        [('cost', 'quality'), ('cost', 'location'), ('location', 'no_of_people')]
# -145299.63639988296        [('quality', 'cost'), ('cost', 'location'), ('location', 'no_of_people')]
# -145299.63639988296        [('cost', 'quality'), ('location', 'no_of_people'), ('location', 'cost')]
# -145299.63639988296        [('no_of_people', 'location'), ('cost', 'quality'), ('location', 'cost')]
# -145284.80326403936        [('no_of_people', 'quality'), ('cost', 'quality'), ('cost', 'location'), ('location', 'no_of_people')]
# -145284.80326403936        [('no_of_people', 'quality'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'cost')]
# -145284.80326403936        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('cost', 'quality'), ('location', 'cost')]
# -145267.30454383342        [('no_of_people', 'location'), ('quality', 'location'), ('cost', 'quality')]
# -145267.30454383342        [('no_of_people', 'location'), ('quality', 'cost'), ('quality', 'location')]
# -145252.47140798983        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('quality', 'location'), ('cost', 'quality')]
# -145174.11048754578        [('no_of_people', 'quality'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'quality')]
# -145174.11048754578        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('cost', 'quality'), ('location', 'quality')]
# -145135.61120537145        [('cost', 'quality'), ('location', 'no_of_people'), ('location', 'quality')]
# -145135.61120537145        [('no_of_people', 'location'), ('cost', 'quality'), ('location', 'quality')]
# -145070.00669670317        [('no_of_people', 'quality'), ('cost', 'quality'), ('cost', 'location'), ('location', 'no_of_people'), ('location', 'quality')]
# -145070.00669670317        [('no_of_people', 'quality'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -145070.00669670317        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('cost', 'quality'), ('location', 'quality'), ('location', 'cost')]
# -145031.50741452884        [('cost', 'quality'), ('cost', 'location'), ('location', 'no_of_people'), ('location', 'quality')]
# -145031.50741452884        [('quality', 'location'), ('cost', 'quality'), ('cost', 'location'), ('location', 'no_of_people')]
# -145031.50741452884        [('quality', 'cost'), ('quality', 'location'), ('cost', 'location'), ('location', 'no_of_people')]
# -145031.50741452884        [('cost', 'quality'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -145031.50741452884        [('no_of_people', 'location'), ('cost', 'quality'), ('location', 'quality'), ('location', 'cost')]
# -145031.50741452884        [('quality', 'cost'), ('quality', 'location'), ('location', 'no_of_people'), ('location', 'cost')]
# -145031.50741452884        [('no_of_people', 'location'), ('quality', 'cost'), ('location', 'quality'), ('location', 'cost')]
# -145031.5074145288        [('quality', 'cost'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -145021.2235338013        [('no_of_people', 'location'), ('quality', 'cost'), ('location', 'cost')]
# -145021.22353380127        [('quality', 'cost'), ('location', 'no_of_people'), ('location', 'cost')]
# -144884.78788690915        [('no_of_people', 'location'), ('quality', 'cost'), ('quality', 'location'), ('location', 'cost')]
# -144877.73968425422        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('cost', 'quality')]
# -144877.73968425422        [('no_of_people', 'quality'), ('quality', 'cost'), ('location', 'no_of_people')]
# -144877.73968425422        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('quality', 'cost')]
# -144877.73968425422        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'cost')]
# -144845.33550054085        [('no_of_people', 'cost'), ('quality', 'cost'), ('location', 'quality'), ('location', 'cost')]
# -144845.33550054085        [('no_of_people', 'cost'), ('quality', 'cost'), ('quality', 'location'), ('location', 'cost')]
# -144835.0516198133        [('no_of_people', 'cost'), ('quality', 'cost'), ('location', 'cost')]
# -144741.30403736208        [('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'quality'), ('location', 'no_of_people')]
# -144741.30403736208        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'quality')]
# -144741.30403736208        [('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('location', 'no_of_people')]
# -144741.30403736208        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('quality', 'cost'), ('location', 'quality')]
# -144741.30403736208        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('quality', 'cost'), ('quality', 'location')]
# -144741.30403736208        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location')]
# -144741.30403736205        [('no_of_people', 'quality'), ('quality', 'cost'), ('location', 'no_of_people'), ('location', 'quality')]
# -144741.30403736205        [('quality', 'no_of_people'), ('quality', 'cost'), ('location', 'no_of_people'), ('location', 'quality')]
# -144731.0201566345        [('quality', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people')]
# -144731.0201566345        [('quality', 'no_of_people'), ('quality', 'cost'), ('location', 'no_of_people')]
# -144626.91636579193        [('quality', 'no_of_people'), ('cost', 'quality'), ('cost', 'location'), ('location', 'no_of_people')]
# -144626.91636579193        [('quality', 'no_of_people'), ('quality', 'cost'), ('cost', 'location'), ('location', 'no_of_people')]
# -144626.91636579193        [('quality', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'cost')]
# -144495.22302732995        [('no_of_people', 'quality'), ('quality', 'cost'), ('location', 'no_of_people'), ('location', 'cost')]
# -144495.22302732995        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('quality', 'cost'), ('location', 'cost')]
# -144495.22302732995        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'cost'), ('location', 'cost')]
# -144462.8911712804        [('quality', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'quality')]
# -144402.24516962958        [('no_of_people', 'cost'), ('cost', 'quality'), ('location', 'cost')]
# -144387.412033786        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('cost', 'quality'), ('location', 'cost')]
# -144358.7873804378        [('quality', 'no_of_people'), ('cost', 'quality'), ('cost', 'location'), ('location', 'no_of_people'), ('location', 'quality')]
# -144358.7873804378        [('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'quality'), ('cost', 'location'), ('location', 'no_of_people')]
# -144358.7873804378        [('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'location'), ('location', 'no_of_people')]
# -144358.7873804378        [('quality', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -144358.7873804378        [('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('location', 'no_of_people'), ('location', 'cost')]
# -144358.7873804378        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('quality', 'cost'), ('location', 'quality'), ('location', 'cost')]
# -144358.7873804378        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('quality', 'cost'), ('quality', 'location'), ('location', 'cost')]
# -144358.7873804378        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('location', 'cost')]
# -144358.78738043777        [('no_of_people', 'quality'), ('quality', 'cost'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -144358.78738043777        [('quality', 'no_of_people'), ('quality', 'cost'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -144348.50349971023        [('quality', 'no_of_people'), ('quality', 'cost'), ('location', 'no_of_people'), ('location', 'cost')]
# -144319.3349940695        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('quality', 'cost'), ('quality', 'location'), ('location', 'cost')]
# -144319.3349940695        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('location', 'cost')]
# -144319.33499406948        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'cost'), ('location', 'quality'), ('location', 'cost')]
# -144309.05111334193        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('quality', 'cost'), ('location', 'cost')]
# -144309.05111334193        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'cost'), ('location', 'cost')]
# -144172.61546644982        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('cost', 'quality'), ('location', 'quality'), ('location', 'cost')]
# -144172.61546644982        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('quality', 'cost'), ('location', 'quality'), ('location', 'cost')]
# -144134.11618427548        [('no_of_people', 'cost'), ('cost', 'quality'), ('location', 'quality'), ('location', 'cost')]
# -143864.17101641386        [('no_of_people', 'location'), ('cost', 'quality'), ('cost', 'location')]
# -143864.17101641383        [('no_of_people', 'location'), ('quality', 'cost'), ('cost', 'location')]
# -143849.33788057027        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('cost', 'quality'), ('cost', 'location')]
# -143653.2259685108        [('no_of_people', 'cost'), ('quality', 'cost'), ('location', 'no_of_people'), ('location', 'quality')]
# -143653.2259685108        [('no_of_people', 'cost'), ('quality', 'cost'), ('quality', 'location'), ('location', 'no_of_people')]
# -143653.22596851076        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'cost'), ('location', 'quality')]
# -143649.37444907767        [('no_of_people', 'location'), ('quality', 'location'), ('cost', 'quality'), ('cost', 'location')]
# -143649.37444907764        [('no_of_people', 'location'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'location')]
# -143642.94208778325        [('no_of_people', 'cost'), ('quality', 'cost'), ('location', 'no_of_people')]
# -143642.94208778322        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'cost')]
# -143634.54131323408        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('cost', 'quality'), ('cost', 'location'), ('location', 'quality')]
# -143634.54131323408        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('quality', 'location'), ('cost', 'quality'), ('cost', 'location')]
# -143596.04203105974        [('no_of_people', 'location'), ('cost', 'quality'), ('cost', 'location'), ('location', 'quality')]
# -143506.50644089107        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'cost'), ('quality', 'location')]
# -143338.17050994252        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('cost', 'quality'), ('cost', 'location')]
# ...
# -142980.50593441975        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'location'), ('cost', 'quality')]
# -142980.50593441975        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('quality', 'cost'), ('location', 'no_of_people'), ('location', 'quality')]
# -142980.50593441975        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'cost'), ('location', 'no_of_people'), ('location', 'quality')]
# -142980.50593441975        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('location', 'no_of_people')]
# -142980.50593441972        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'quality')]
# -142980.50593441972        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'quality')]
# -142980.50593441972        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'no_of_people')]
# -142980.50593441972        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'cost'), ('location', 'quality')]
# -142980.50593441972        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'cost'), ('quality', 'location')]
# -142980.50593441972        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location')]
# -142970.2220536922        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'cost'), ('location', 'no_of_people')]
# -142902.1450139757        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('cost', 'quality'), ('location', 'quality')]
# -142902.14501397568        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'quality')]
# -142902.14501397568        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'quality')]
# -142863.64573180137        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('cost', 'quality'), ('location', 'quality')]
# -142863.64573180134        [('no_of_people', 'location'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'quality')]
# -142863.64573180134        [('no_of_people', 'cost'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'quality')]
# -142103.3729134715        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'cost'), ('cost', 'location')]
# -142035.295873755        [('no_of_people', 'cost'), ('quality', 'cost'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -142035.295873755        [('no_of_people', 'cost'), ('quality', 'cost'), ('quality', 'location'), ('location', 'no_of_people'), ('location', 'cost')]
# -142035.295873755        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'cost'), ('location', 'quality'), ('location', 'cost')]
# -142025.01199302747        [('no_of_people', 'cost'), ('quality', 'cost'), ('location', 'no_of_people'), ('location', 'cost')]
# -142025.01199302747        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'cost'), ('location', 'cost')]
# -141888.57634613532        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'location')]
# -141888.57634613532        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'cost'), ('quality', 'location'), ('location', 'cost')]
# -141745.09249658824        [('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people')]
# -141745.09249658824        [('quality', 'no_of_people'), ('quality', 'cost'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'quality')]
# -141745.09249658824        [('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'no_of_people'), ('location', 'no_of_people')]
# -141734.8086158607        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people')]
# -141734.8086158607        [('quality', 'no_of_people'), ('quality', 'cost'), ('cost', 'no_of_people'), ('location', 'no_of_people')]
# -141706.5932144139        [('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people')]
# -141706.5932144139        [('quality', 'cost'), ('quality', 'location'), ('cost', 'no_of_people'), ('location', 'no_of_people')]
# -141706.59321441388        [('quality', 'cost'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'quality')]
# -141696.30933368637        [('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people')]
# -141696.30933368634        [('quality', 'cost'), ('cost', 'no_of_people'), ('location', 'no_of_people')]
# -141681.47619784274        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people')]
# -141630.7048250181        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location'), ('location', 'no_of_people')]
# -141630.7048250181        [('quality', 'no_of_people'), ('quality', 'cost'), ('cost', 'no_of_people'), ('cost', 'location'), ('location', 'no_of_people')]
# -141630.7048250181        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'cost')]
# -141592.20554284376        [('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location'), ('location', 'no_of_people')]
# -141592.20554284376        [('no_of_people', 'location'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location')]
# -141592.20554284376        [('no_of_people', 'location'), ('quality', 'cost'), ('cost', 'no_of_people'), ('cost', 'location')]
# -141592.20554284376        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('cost', 'quality'), ('cost', 'location')]
# -141592.20554284376        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('cost', 'quality'), ('location', 'cost')]
# -141592.20554284373        [('quality', 'cost'), ('cost', 'no_of_people'), ('cost', 'location'), ('location', 'no_of_people')]
# -141592.20554284373        [('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'cost')]
# -141592.20554284373        [('no_of_people', 'cost'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'cost')]
# -141577.37240700016        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location'), ('location', 'no_of_people')]
# -141577.37240700016        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location')]
# -141577.37240700016        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location')]
# -141577.37240700016        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'cost'), ('cost', 'no_of_people'), ('cost', 'location')]
# -141577.37240700016        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('cost', 'quality'), ('cost', 'location')]
# -141577.37240700016        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'cost'), ('cost', 'location')]
# -141577.37240700016        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'cost'), ('cost', 'location')]
# -141577.37240700016        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'cost')]
# -141577.37240700016        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'cost')]
# -141577.37240700016        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('cost', 'quality'), ('location', 'cost')]
# -141499.01148655612        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('quality', 'cost'), ('location', 'no_of_people'), ('location', 'cost')]
# -141499.01148655612        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'cost'), ('location', 'cost')]
# -141499.01148655612        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'cost'), ('location', 'cost')]
# -141466.67963050655        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'quality')]
# -141466.67963050655        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'quality')]
# -141428.18034833221        [('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'quality')]
# -141377.4089755076        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'location'), ('cost', 'quality'), ('cost', 'location')]
# -141377.40897550757        [('no_of_people', 'location'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location')]
# -141377.40897550757        [('no_of_people', 'location'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'location')]
# -141362.57583966397        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location'), ('location', 'no_of_people'), ('location', 'quality')]
# -141362.57583966397        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location'), ('location', 'no_of_people'), ('location', 'quality')]
# -141362.57583966397        [('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location'), ('location', 'no_of_people')]
# -141362.57583966397        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location'), ('location', 'quality')]
# -141362.57583966397        [('no_of_people', 'quality'), ('no_of_people', 'location'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location')]
# -141362.57583966397        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location')]
# -141362.57583966397        [('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'location'), ('location', 'no_of_people')]
# -141362.57583966397        [('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'location')]
# -141362.57583966397        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('cost', 'quality'), ('cost', 'location'), ('location', 'quality')]
# -141362.57583966397        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'location'), ('cost', 'quality'), ('cost', 'location')]
# -141362.57583966397        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'location')]
# -141362.57583966397        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'location')]
# -141362.57583966397        [('no_of_people', 'quality'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -141362.57583966397        [('quality', 'no_of_people'), ('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -141362.57583966397        [('quality', 'no_of_people'), ('quality', 'cost'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -141362.57583966397        [('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'cost')]
# -141362.57583966397        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -141362.57583966397        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('cost', 'quality'), ('location', 'quality'), ('location', 'cost')]
# -141362.57583966397        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('quality', 'cost'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -141362.57583966397        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'cost'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -141362.57583966397        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('location', 'no_of_people'), ('location', 'cost')]
# -141362.57583966397        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'cost'), ('location', 'quality'), ('location', 'cost')]
# -141362.57583966397        [('no_of_people', 'quality'), ('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'cost'), ('quality', 'location'), ('location', 'cost')]
# -141362.57583966397        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('quality', 'no_of_people'), ('quality', 'cost'), ('quality', 'location'), ('location', 'cost')]
# -141352.29195893643        [('quality', 'no_of_people'), ('quality', 'cost'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'cost')]
# -141352.29195893643        [('no_of_people', 'cost'), ('quality', 'no_of_people'), ('quality', 'cost'), ('location', 'no_of_people'), ('location', 'cost')]
# -141324.07655748964        [('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location'), ('location', 'no_of_people'), ('location', 'quality')]
# -141324.07655748964        [('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location'), ('location', 'no_of_people')]
# -141324.07655748964        [('no_of_people', 'location'), ('cost', 'no_of_people'), ('cost', 'quality'), ('cost', 'location'), ('location', 'quality')]
# -141324.07655748964        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('cost', 'quality'), ('cost', 'location'), ('location', 'quality')]
# -141324.07655748964        [('cost', 'no_of_people'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -141324.07655748964        [('quality', 'cost'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -141324.07655748964        [('quality', 'cost'), ('quality', 'location'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'cost')]
# -141324.07655748964        [('no_of_people', 'cost'), ('cost', 'quality'), ('location', 'no_of_people'), ('location', 'quality'), ('location', 'cost')]
# -141324.07655748964        [('no_of_people', 'cost'), ('no_of_people', 'location'), ('cost', 'quality'), ('location', 'quality'), ('location', 'cost')]
# -141324.0765574896        [('quality', 'cost'), ('quality', 'location'), ('cost', 'no_of_people'), ('cost', 'location'), ('location', 'no_of_people')]
# -141313.7926767621        [('quality', 'cost'), ('cost', 'no_of_people'), ('location', 'no_of_people'), ('location', 'cost')]

# %% [markdown]
# ## Parameter Learning
# Uses above **best_model**

# %% [markdown]
# ### MaximumLikelihoodEstimator

# %%
from pgmpy.estimators import MaximumLikelihoodEstimator
estimator_type = MaximumLikelihoodEstimator
best_model.fit(df, estimator=estimator_type)

# %%
#best_model.get_cpds()
for cpd in best_model.get_cpds():
    print('cpd for variable %s:\n%s\n' % (cpd.variable, str(cpd)))
# Out:
# cpd for variable cost:
# ╒══════════╤═════════════════════╤════════════════════╤═════════════════════╤════════════════════╤════════════════════╤═════════════════════╕
# │ location │ location(0)         │ location(0)        │ location(0)         │ location(1)        │ location(1)        │ location(1)         │
# ├──────────┼─────────────────────┼────────────────────┼─────────────────────┼────────────────────┼────────────────────┼─────────────────────┤
# │ quality  │ quality(0)          │ quality(1)         │ quality(2)          │ quality(0)         │ quality(1)         │ quality(2)          │
# ├──────────┼─────────────────────┼────────────────────┼─────────────────────┼────────────────────┼────────────────────┼─────────────────────┤
# │ cost(0)  │ 0.7977994835522623  │ 0.6006169114195669 │ 0.10415631727107137 │ 0.5983593109105825 │ 0.6048185544336699 │ 0.05095226317091269 │
# ├──────────┼─────────────────────┼────────────────────┼─────────────────────┼────────────────────┼────────────────────┼─────────────────────┤
# │ cost(1)  │ 0.20220051644773773 │ 0.3993830885804332 │ 0.8958436827289287  │ 0.4016406890894176 │ 0.3951814455663301 │ 0.9490477368290873  │
# ╘══════════╧═════════════════════╧════════════════════╧═════════════════════╧════════════════════╧════════════════════╧═════════════════════╛
#
# cpd for variable location:
# ╒═════════════╤═════════╕
# │ location(0) │ 0.59718 │
# ├─────────────┼─────────┤
# │ location(1) │ 0.40282 │
# ╘═════════════╧═════════╛
#
# cpd for variable no_of_people:
# ╒═════════════════╤═════════════════════╤═════════════════════╤═════════════════════╤════════════════════╕
# │ cost            │ cost(0)             │ cost(0)             │ cost(1)             │ cost(1)            │
# ├─────────────────┼─────────────────────┼─────────────────────┼─────────────────────┼────────────────────┤
# │ location        │ location(0)         │ location(1)         │ location(0)         │ location(1)        │
# ├─────────────────┼─────────────────────┼─────────────────────┼─────────────────────┼────────────────────┤
# │ no_of_people(0) │ 0.6056194584231968  │ 0.09774815712410381 │ 0.8013214855320119  │ 0.6019730416096893 │
# ├─────────────────┼─────────────────────┼─────────────────────┼─────────────────────┼────────────────────┤
# │ no_of_people(1) │ 0.39438054157680325 │ 0.9022518428758962  │ 0.19867851446798815 │ 0.3980269583903106 │
# ╘═════════════════╧═════════════════════╧═════════════════════╧═════════════════════╧════════════════════╛
#
# cpd for variable quality:
# ╒════════════╤═════════╕
# │ quality(0) │ 0.30004 │
# ├────────────┼─────────┤
# │ quality(1) │ 0.49832 │
# ├────────────┼─────────┤
# │ quality(2) │ 0.20164 │
# ╘════════════╧═════════╛

# %% [markdown]
# ### BayesianEstimator

# %%
from pgmpy.estimators import BayesianEstimator
estimator = BayesianEstimator(best_model, df)
#for cpd in estimator.get_parameters(prior_type='dirichlet', \
#    pseudo_counts={'cost': [0.01, 0.01], 'quality': [0.01, 0.01, 0.01], \
#                   'location': [0.01, 0.01], 'no_of_people': [0.01, 0.01]}):
for cpd in estimator.get_parameters(prior_type='K2'):
    print('cpd for variable %s:\n%s\n' % (cpd.variable, str(cpd)))
# Out:
# cpd for variable quality:
# ╒════════════╤══════════╕
# │ quality(0) │ 0.300042 │
# ├────────────┼──────────┤
# │ quality(1) │ 0.49831  │
# ├────────────┼──────────┤
# │ quality(2) │ 0.201648 │
# ╘════════════╧══════════╛
#
# cpd for variable no_of_people:
# ╒═════════════════╤════════════════════╤════════════════════╤═════════════════════╤═════════════╕
# │ cost            │ cost(0)            │ cost(0)            │ cost(1)             │ cost(1)     │
# ├─────────────────┼────────────────────┼────────────────────┼─────────────────────┼─────────────┤
# │ location        │ location(0)        │ location(1)        │ location(0)         │ location(1) │
# ├─────────────────┼────────────────────┼────────────────────┼─────────────────────┼─────────────┤
# │ no_of_people(0) │ 0.6056068048400624 │ 0.0978293791014639 │ 0.8012757232895437  │ 0.601953125 │
# ├─────────────────┼────────────────────┼────────────────────┼─────────────────────┼─────────────┤
# │ no_of_people(1) │ 0.3943931951599377 │ 0.9021706208985361 │ 0.19872427671045637 │ 0.398046875 │
# ╘═════════════════╧════════════════════╧════════════════════╧═════════════════════╧═════════════╛
#
# cpd for variable cost:
# ╒══════════╤═════════════════════╤═════════════════════╤═════════════════════╤════════════════════╤════════════════════╤════════════════════╕
# │ location │ location(0)         │ location(0)         │ location(0)         │ location(1)        │ location(1)        │ location(1)        │
# ├──────────┼─────────────────────┼─────────────────────┼─────────────────────┼────────────────────┼────────────────────┼────────────────────┤
# │ quality  │ quality(0)          │ quality(1)          │ quality(2)          │ quality(0)         │ quality(1)         │ quality(2)         │
# ├──────────┼─────────────────────┼─────────────────────┼─────────────────────┼────────────────────┼────────────────────┼────────────────────┤
# │ cost(0)  │ 0.7977326299247951  │ 0.6006034193764667  │ 0.10428736964078796 │ 0.5983270460882402 │ 0.6047976011994003 │ 0.0511742892459827 │
# ├──────────┼─────────────────────┼─────────────────────┼─────────────────────┼────────────────────┼────────────────────┼────────────────────┤
# │ cost(1)  │ 0.20226737007520484 │ 0.39939658062353334 │ 0.895712630359212   │ 0.4016729539117599 │ 0.3952023988005997 │ 0.9488257107540173 │
# ╘══════════╧═════════════════════╧═════════════════════╧═════════════════════╧════════════════════╧════════════════════╧════════════════════╛
#
# cpd for variable location:
# ╒═════════════╤══════════╕
# │ location(0) │ 0.597176 │
# ├─────────────┼──────────┤
# │ location(1) │ 0.402824 │
# ╘═════════════╧══════════╛

# %% [markdown]
# ## Scoring methods - how well data maps to a model

# %%
import pandas as pd

import numpy as np
from pgmpy.estimators import K2Score, BdeuScore, BicScore
# create random data sample with 3 variables, where B and C are identical:
data = pd.DataFrame(np.random.randint(0, 5, size=(5000, 2)), columns=list('AB'))
data['C'] = data['B']
model_AB_AC=BayesianModel([['A','B'], ['A','C']])
model_AB_BC=BayesianModel([['A','B'], ['B','C']])
model_BC=BayesianModel([['B','C']]) # the best model, as per data construction
model_CB=BayesianModel([['C','B']]) # the best model, as per data construction

print('K2Score AB_AC: %.5f' % K2Score(data).score(model_AB_AC))
print('K2Score AB_BC: %.5f' % K2Score(data).score(model_AB_BC))
print('K2Score BC: %.5f' % K2Score(data).score(model_BC))
print('K2Score CB: %.5f' % K2Score(data).score(model_CB))
print

print('BicScore AB_AC: %.5f' % BicScore(data).score(model_AB_AC))
print('BicScore AB_BC: %.5f' % BicScore(data).score(model_AB_BC))
print('BicScore BC: %.5f' % BicScore(data).score(model_BC))
print('BicScore CB: %.5f' % BicScore(data).score(model_CB))
print

print('BdeuScore AB_AC: %.5f' % BdeuScore(data).score(model_AB_AC))
print('BdeuScore AB_BC: %.5f' % BdeuScore(data).score(model_AB_BC))
print('BdeuScore BC: %.5f' % BdeuScore(data).score(model_BC))
print('BdeuScore CB: %.5f' % BdeuScore(data).score(model_CB))
# Out:
# K2Score AB_AC: -24247.54442
# K2Score AB_BC: -16276.56271
# K2Score BC: -8181.68648
# K2Score CB: -8181.68648
# BicScore AB_AC: -24310.74096
# BicScore AB_BC: -16272.44038
# BicScore BC: -8147.37928
# BicScore CB: -8147.37928
# BdeuScore AB_AC: -24269.18819
# BdeuScore AB_BC: -16223.53859
# BdeuScore BC: -8117.05498
# BdeuScore CB: -8117.05498
